# %% [markdown]
# # Customer Churn Prediction & Risk Segmentation
#
# ## Objective
#
# This notebook demonstrates how the final machine learning model can be used to predict customer churn on new customer data.
#
# The workflow includes:
#
# - Loading the production-ready model
# - Loading the preprocessing pipeline
# - Predicting customer churn
# - Calculating churn probabilities
# - Creating customer risk segments
# - Generating business-ready prediction reports
# - Exporting results for the marketing team

# %%
import pandas as pd
import numpy as np
import joblib

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/processed/customer_churn_clean.csv")

df.head()
# Out:
#    Customer_ID            Name  Age  Gender     Location Registration_Date  \
# 0  CUST-034287  Fahad Siddiqui   38    Male   rawalpindi        2026-06-07
# 1  CUST-039794    Komal Sheikh   30  Female   rawalpindi        2026-04-02
# 2  CUST-006671      Rabia Raza   26  Female       multan        2025-07-19
# 3  CUST-010452   Sarah Hussain   27  Female       quetta        2024-09-04
# 4  CUST-046710      Anum Mirza   20  Female  los angeles        2024-10-17
#
#   Last_Purchase_Date  Purchase_Frequency  Total_Spending  Average_Order_Value  \
# 0         2025-06-20                   1           89.32                94.17
# 1         2025-06-20                   2           97.49                52.82
# 2         2025-06-20                   2           90.51                38.74
# 3         2025-06-20                   3          241.42                77.81
# 4         2025-06-20                   1           37.53                32.14
#
# ...

# %%
model = joblib.load(model_path)
preprocessor = joblib.load(preprocessor_path)

preprocessor = joblib.load("../models/preprocessor.pkl")
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 model = joblib.load("../models/churn_model.pkl")
#       3 preprocessor = joblib.load("../models/preprocessor.pkl")
#
# File c:\Users\AK\anaconda3\Lib\site-packages\joblib\numpy_pickle.py:658, in load(filename, mmap_mode)
#     652             if isinstance(fobj, str):
#     653                 # if the returned file object is a string, this means we
#     654                 # try to load a pickle file generated with an version of
#     655                 # Joblib so we load it with joblib compatibility function.
#     656                 return load_compatibility(fobj)
# --> 658             obj = _unpickle(fobj, filename, mmap_mode)
#     659 return obj
#
# File c:\Users\AK\anaconda3\Lib\site-packages\joblib\numpy_pickle.py:577, in _unpickle(fobj, filename, mmap_mode)
#     575 obj = None
# ...
